# %% [markdown]
# # Melanoma Detection Assignment

# %% [markdown]
# ## Problem statement

# %% [markdown]
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# The dataset consists of 2357 images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC). All images were sorted according to the classification taken with ISIC

# %% [markdown]
# We will go through following steps to acheive goal:

# %% [markdown]
# #### Steps
# 1. Importing and Loading Data
# 1. Dataset Creation
# 1. Dataset visualisation
# 1. Model Building & training
# 1. Resolve underfitting/overfitting
# 1. Model Building & training on the augmented data
# 1. Examine class distribution
# 1. Handling class imbalances
# 1. Model Building & training on the rectified class imbalance data
# 1. Conclusion

# %% [markdown]
# ## 1. Importing and Loading Data

# %% [markdown]
# #### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential


import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path('/content/drive/MyDrive/MELONOMA_D_A/Train')
data_dir_test = pathlib.Path('/content/drive/MyDrive/MELONOMA_D_A/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print("Training Images Count : ", image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print("Testing Images Count  :  ", image_count_test)
# Out:
# Training Images Count :  2239
# Testing Images Count  :   118

# %% [markdown]
# ## 2. Dataset Creation

# %% [markdown]
# #### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# We will define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split=0.2,
  subset="training",
  image_size=(img_height, img_width),
  batch_size=None)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split=0.2,
  subset="validation",
  image_size=(img_height, img_width),
  batch_size=None)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ## 3. Visualize the data

# %%
import matplotlib.pyplot as plt

# Loading single image of single calss from dictionary
image = plt.imread(str(list(data_dir_train.glob(class_names[0]+'/*.jpg'))[0]))
plt.imshow(image)

# %%
# Loading single image from each class
plt.figure(figsize=(15,15))
for i in range(9):
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[0]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
# Performance tunning

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(len(train_ds)).batch(batch_size).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 4. Model Building & training

# %% [markdown]
# ### Create the model

# %% [markdown]
# We will create a CNN model using ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %% [markdown]
# We will put this model into a function since we want to check the effects of class imabalance and class distribution in following steps so we should keep the model same through out to check the effects.

# %%
def get_model():
    # CNN Model
    model= Sequential()
    # scaling the pixel values from 0-255 to 0-1
    model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))

    # Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
    model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
    model.add(layers.MaxPooling2D())

    # Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
    model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
    model.add(layers.MaxPooling2D())

    # Convolution layer with 256 features, 3x3 filter
    model.add(layers.Conv2D(256,(3,3),padding = 'same',activation='relu'))

    model.add(layers.Flatten())
    model.add(layers.Dense(9,activation='softmax'))

    return model

# %% [markdown]
# ### Compile the model
# We will Choose an appropirate optimiser and loss function for model training

# %%
#Compile the Model
model = get_model()
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 128)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 256)       295168
#
#  flatten (Flatten)           (None, 518400)            0
#
#  dense (Dense)               (None, 9)                 4665609
#
# =================================================================
# Total params: 5036425 (19.21 MB)
# Trainable params: 5036425 (19.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 1475s 2s/step - loss: 2.0131 - accuracy: 0.2849 - val_loss: 1.8939 - val_accuracy: 0.3207
# Epoch 2/20
# 169/169 [==============================] - 13s 76ms/step - loss: 1.5124 - accuracy: 0.4447 - val_loss: 1.2839 - val_accuracy: 0.5330
# Epoch 3/20
# 169/169 [==============================] - 13s 74ms/step - loss: 1.2949 - accuracy: 0.5282 - val_loss: 1.2863 - val_accuracy: 0.5293
# Epoch 4/20
# 169/169 [==============================] - 12s 74ms/step - loss: 1.1195 - accuracy: 0.5899 - val_loss: 1.3744 - val_accuracy: 0.5241
# Epoch 5/20
# 169/169 [==============================] - 12s 74ms/step - loss: 1.0007 - accuracy: 0.6500 - val_loss: 1.1099 - val_accuracy: 0.6036
# Epoch 6/20
# 169/169 [==============================] - 13s 75ms/step - loss: 0.9120 - accuracy: 0.6725 - val_loss: 1.0146 - val_accuracy: 0.6459
# Epoch 7/20
# 169/169 [==============================] - 13s 75ms/step - loss: 0.7607 - accuracy: 0.7289 - val_loss: 1.0712 - val_accuracy: 0.6325
# Epoch 8/20
# 169/169 [==============================] - 13s 74ms/step - loss: 0.6989 - accuracy: 0.7559 - val_loss: 1.0376 - val_accuracy: 0.6800
# Epoch 9/20
# 169/169 [==============================] - 13s 75ms/step - loss: 0.6395 - accuracy: 0.7778 - val_loss: 0.9447 - val_accuracy: 0.6785
# Epoch 10/20
# 169/169 [==============================] - 13s 74ms/step - loss: 0.5367 - accuracy: 0.8119 - val_loss: 1.0860 - val_accuracy: 0.7090
# Epoch 11/20
# 169/169 [==============================] - 13s 74ms/step - loss: 0.4707 - accuracy: 0.8361 - val_loss: 1.3273 - val_accuracy: 0.6696
# Epoch 12/20
# 169/169 [==============================] - 12s 74ms/step - loss: 0.4974 - accuracy: 0.8320 - val_loss: 0.9537 - val_accuracy: 0.7431
# Epoch 13/20
# 169/169 [==============================] - 12s 74ms/step - loss: 0.3864 - accuracy: 0.8663 - val_loss: 1.0846 - val_accuracy: 0.7498
# Epoch 14/20
# 169/169 [==============================] - 12s 73ms/step - loss: 0.3422 - accuracy: 0.8822 - val_loss: 0.9645 - val_accuracy: 0.7520
# Epoch 15/20
# 169/169 [==============================] - 12s 73ms/step - loss: 0.3189 - accuracy: 0.8924 - val_loss: 1.5594 - val_accuracy: 0.7075
# Epoch 16/20
# 169/169 [==============================] - 13s 76ms/step - loss: 0.3318 - accuracy: 0.8945 - val_loss: 1.0979 - val_accuracy: 0.7528
# Epoch 17/20
# 169/169 [==============================] - 13s 74ms/step - loss: 0.2893 - accuracy: 0.9104 - val_loss: 0.9716 - val_accuracy: 0.7610
# Epoch 18/20
# 169/169 [==============================] - 12s 74ms/step - loss: 0.2674 - accuracy: 0.9151 - val_loss: 0.9670 - val_accuracy: 0.7610
# Epoch 19/20
# 169/169 [==============================] - 12s 74ms/step - loss: 0.2161 - accuracy: 0.9332 - val_loss: 1.1223 - val_accuracy: 0.7543
# Epoch 20/20
# 169/169 [==============================] - 12s 74ms/step - loss: 0.2737 - accuracy: 0.9169 - val_loss: 1.0464 - val_accuracy: 0.7416

# %% [markdown]
# ### Visualizing training results

# %%
def visualizing_result(history,epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

visualizing_result(history,epochs)

# %% [markdown]
# <font color='blue'>**Observation**</font> : <br>
# - We can observe that the training accuracy increases linearly over time, but the validation accuracy saturates around 50% while training
# - Training loss and validation loss are showing inverse relation
# - We can observe **overfiting** of the model as there is significant difference in accuracy of training and validation data set and training accuracy is very high compare to validation accuracy

# %% [markdown]
# ## 5. Resolve overfitting

# %% [markdown]
# We need to fix overfiting by introducing diversity in samples in training data set which will help our model to train on diverse data set and avoid overfiting.

# %% [markdown]
# For this we will use augmentation strategy to generate diverse images using our existing data set.

# %%
tf.get_logger().setLevel('ERROR')

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal_and_vertical",input_shape=(img_height,img_width,3)),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1)
  ]
)

# %%
# visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ## 6. Model Building & training on the augmented data

# %% [markdown]
# ### Create the model, compile and train the model

# %%
def get_model_with_dropout():
    # CNN Model
    model= Sequential()
    # scaling the pixel values from 0-255 to 0-1
    model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))
    model.add(data_augmentation)

    # Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
    model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
    model.add(layers.MaxPooling2D())

    # Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
    model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
    model.add(layers.MaxPooling2D())
    #adding a 20% dropout after the convolution layers
    model.add(layers.Dropout(0.2))

    # Convolution layer with 256 features, 3x3 filter
    model.add(layers.Conv2D(256,(3,3),padding = 'same',activation='relu'))
    #adding a 10% dropout
    model.add(layers.Dropout(0.1))

    model.add(layers.Flatten())
    model.add(layers.Dense(9,activation='softmax'))

    return model

# %% [markdown]
# ### Compiling the model

# %%
#Compile the Model with dropout
model = get_model_with_dropout()
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 64)      1792
#
#  max_pooling2d_2 (MaxPoolin  (None, 90, 90, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_3 (MaxPoolin  (None, 45, 45, 128)       0
#  g2D)
#
#  dropout (Dropout)           (None, 45, 45, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 256)       295168
#
#  dropout_1 (Dropout)         (None, 45, 45, 256)       0
#
#  flatten_1 (Flatten)         (None, 518400)            0
#
#  dense_1 (Dense)             (None, 9)                 4665609
#
# =================================================================
# Total params: 5036425 (19.21 MB)
# Trainable params: 5036425 (19.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 24s 126ms/step - loss: 2.3013 - accuracy: 0.1358 - val_loss: 2.1889 - val_accuracy: 0.1351
# Epoch 2/20
# 169/169 [==============================] - 21s 122ms/step - loss: 2.1761 - accuracy: 0.1471 - val_loss: 2.1582 - val_accuracy: 0.1359
# Epoch 3/20
# 169/169 [==============================] - 21s 123ms/step - loss: 2.1574 - accuracy: 0.1608 - val_loss: 2.1646 - val_accuracy: 0.1440
# Epoch 4/20
# 169/169 [==============================] - 20s 118ms/step - loss: 2.0667 - accuracy: 0.2047 - val_loss: 1.7952 - val_accuracy: 0.2866
# Epoch 5/20
# 169/169 [==============================] - 20s 116ms/step - loss: 1.8063 - accuracy: 0.2947 - val_loss: 1.9047 - val_accuracy: 0.2279
# Epoch 6/20
# 169/169 [==============================] - 19s 113ms/step - loss: 1.6675 - accuracy: 0.3631 - val_loss: 1.5223 - val_accuracy: 0.4001
# Epoch 7/20
# 169/169 [==============================] - 19s 115ms/step - loss: 1.5510 - accuracy: 0.3999 - val_loss: 1.5719 - val_accuracy: 0.4046
# Epoch 8/20
# 169/169 [==============================] - 19s 113ms/step - loss: 1.5334 - accuracy: 0.4023 - val_loss: 1.5394 - val_accuracy: 0.4046
# Epoch 9/20
# 169/169 [==============================] - 19s 114ms/step - loss: 1.4945 - accuracy: 0.4175 - val_loss: 1.4240 - val_accuracy: 0.4261
# Epoch 10/20
# 169/169 [==============================] - 19s 112ms/step - loss: 1.4877 - accuracy: 0.4216 - val_loss: 1.3760 - val_accuracy: 0.4722
# Epoch 11/20
# 169/169 [==============================] - 19s 114ms/step - loss: 1.4486 - accuracy: 0.4473 - val_loss: 1.3279 - val_accuracy: 0.4811
# Epoch 12/20
# 169/169 [==============================] - 19s 112ms/step - loss: 1.4209 - accuracy: 0.4544 - val_loss: 1.3177 - val_accuracy: 0.4774
# Epoch 13/20
# 169/169 [==============================] - 19s 114ms/step - loss: 1.4046 - accuracy: 0.4625 - val_loss: 1.2732 - val_accuracy: 0.4937
# Epoch 14/20
# 169/169 [==============================] - 19s 112ms/step - loss: 1.3876 - accuracy: 0.4666 - val_loss: 1.2966 - val_accuracy: 0.5078
# Epoch 15/20
# 169/169 [==============================] - 19s 113ms/step - loss: 1.3566 - accuracy: 0.4766 - val_loss: 1.3583 - val_accuracy: 0.4937
# Epoch 16/20
# 169/169 [==============================] - 19s 112ms/step - loss: 1.3557 - accuracy: 0.4803 - val_loss: 1.2490 - val_accuracy: 0.5174
# Epoch 17/20
# 169/169 [==============================] - 19s 112ms/step - loss: 1.3429 - accuracy: 0.4818 - val_loss: 1.2672 - val_accuracy: 0.5360
# Epoch 18/20
# 169/169 [==============================] - 19s 112ms/step - loss: 1.3164 - accuracy: 0.4967 - val_loss: 1.2443 - val_accuracy: 0.5226
# Epoch 19/20
# 169/169 [==============================] - 19s 113ms/step - loss: 1.3149 - accuracy: 0.4954 - val_loss: 1.2149 - val_accuracy: 0.5137
# Epoch 20/20
# 169/169 [==============================] - 19s 113ms/step - loss: 1.2931 - accuracy: 0.5002 - val_loss: 1.1907 - val_accuracy: 0.5405

# %% [markdown]
# ### Visualizing the results

# %%
visualizing_result(history,epochs)

# %% [markdown]
# <font color='blue'>**Observation**</font> : <br>
# - We can observe that the training accuracy increases linearly over time along with validation accuracy and both saturates around 50% while training
# - Training loss and validation loss are also dicreasing consistently and almost matching with each other
# - We can observe that **overfiting** of the model has **reduced drastically** from previous model results
# - However the model is **not very accurate** and the accuracy of the model is around **50-55%**

# %% [markdown]
# ## 7. Class distribution

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
#checking the class distribution in the training dataset
class_diff=pd.DataFrame()
totalFiles = len(list(data_dir_train.glob('*/*.jpg')))
for i in range(len(class_names)):
  name= class_names[i]
  count = len(list(data_dir_train.glob(f'{class_names[i]}/*.jpg')))
  perc = round(count/totalFiles*100,2)
  class_diff=class_diff.append({'class':name,'images':count,'percentage' : perc},ignore_index=True)
class_diff
# Out:
#                         class  images  percentage
# 0           actinic keratosis     114        5.09
# 1        basal cell carcinoma     376       16.79
# 2              dermatofibroma      95        4.24
# 3                    melanoma     438       19.56
# 4                       nevus     357       15.94
# 5  pigmented benign keratosis     462       20.63
# 6        seborrheic keratosis      77        3.44
# 7     squamous cell carcinoma     181        8.08
# 8             vascular lesion     139        6.21

# %%
# Plotting class distribution
class_diff.plot.bar(x='class',y='percentage',rot=45,figsize=(12,8))
# Out:
# <Axes: xlabel='class'>

# %% [markdown]
# <font color='blue'>**Observation**</font> : <br>
# - **'seborrheic keratosis'** class has the least number of samples
# - **'melanoma', 'nevus', 'pigmented benign keratosis'** and **'basal cell carcinoma'** these classes dominate the data in terms proportionate number of samples

# %% [markdown]
# ## 8. Handling class imbalances

# %% [markdown]
# **Context:** We will use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset='//content//drive//MyDrive//MELONOMA_D_A//Train//'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to //content//drive//MyDrive//MELONOMA_D_A//Train//actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BB2401DF8E0>: 100%|██████████| 500/500 [00:19<00:00, 26.07 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to //content//drive//MyDrive//MELONOMA_D_A//Train//basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7BB1FB92BFD0>: 100%|██████████| 500/500 [00:18<00:00, 27.70 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to //content//drive//MyDrive//MELONOMA_D_A//Train//dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BB240139750>: 100%|██████████| 500/500 [00:18<00:00, 27.48 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to //content//drive//MyDrive//MELONOMA_D_A//Train//melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7BB24C3ACB80>: 100%|██████████| 500/500 [01:25<00:00,  5.86 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to //content//drive//MyDrive//MELONOMA_D_A//Train//nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BB1FB964880>: 100%|██████████| 500/500 [01:21<00:00,  6.11 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to //content//drive//MyDrive//MELONOMA_D_A//Train//pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BB240409D20>: 100%|██████████| 500/500 [00:17<00:00, 28.60 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to //content//drive//MyDrive//MELONOMA_D_A//Train//seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7BB1FB934F70>: 100%|██████████| 500/500 [00:37<00:00, 13.19 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to //content//drive//MyDrive//MELONOMA_D_A//Train//squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BB240409D20>: 100%|██████████| 500/500 [00:18<00:00, 27.06 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to //content//drive//MyDrive//MELONOMA_D_A//Train//vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BB24017F340>: 100%|██████████| 500/500 [00:18<00:00, 27.13 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 9000

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = class_diff.append(df2)

# %%
class_diff['new_images'] = class_diff['class'].map(df2['Label'].value_counts())

# %%
class_diff['total_images'] = class_diff['images'] + class_diff['new_images']

# %%
total_images_count = class_diff.total_images.sum()

# %%
class_diff['final_percentage'] = round(class_diff['total_images'] / total_images_count * 100,2)

# %%
class_diff
# Out:
#                         class  images  percentage  new_images  total_images  \
# 0           actinic keratosis     114        5.09        1000          1114
# 1        basal cell carcinoma     376       16.79        1000          1376
# 2              dermatofibroma      95        4.24        1000          1095
# 3                    melanoma     438       19.56        1000          1438
# 4                       nevus     357       15.94        1000          1357
# 5  pigmented benign keratosis     462       20.63        1000          1462
# 6        seborrheic keratosis      77        3.44        1000          1077
# 7     squamous cell carcinoma     181        8.08        1000          1181
# 8             vascular lesion     139        6.21        1000          1139
#
#    final_percentage
# 0              9.91
# 1             12.24
# 2              9.74
# 3             12.79
# 4             12.07
# 5             13.01
# 6              9.58
# 7             10.51
# 8             10.13

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# ## 9. Model Building & training on the rectified class imbalance data

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
data_dir_train = pathlib.Path('/content/drive/MyDrive/MELONOMA_D_A/Train')
data_dir_test = pathlib.Path('/content/drive/MyDrive/MELONOMA_D_A/Test')

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=None)
# Out:
# Found 11239 files belonging to 9 classes.
# Using 8992 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=None)
# Out:
# Found 11239 files belonging to 9 classes.
# Using 2247 files for validation.

# %%
# Performance tunning

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(len(train_ds)).batch(batch_size).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ####  Create your model (make sure to include normalization)

# %%
#Compile the Model with dropout
model = get_model_with_dropout()

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 64)      1792
#
#  max_pooling2d_4 (MaxPoolin  (None, 90, 90, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 45, 45, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 45, 45, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 256)       295168
#
#  dropout_3 (Dropout)         (None, 45, 45, 256)       0
#
#  flatten_2 (Flatten)         (None, 518400)            0
#
#  dense_2 (Dense)             (None, 9)                 4665609
#
# =================================================================
# Total params: 5036425 (19.21 MB)
# Trainable params: 5036425 (19.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 281/281 [==============================] - 126s 193ms/step - loss: 1.9561 - accuracy: 0.2812 - val_loss: 1.5510 - val_accuracy: 0.3778
# Epoch 2/50
# 281/281 [==============================] - 34s 121ms/step - loss: 1.5213 - accuracy: 0.4103 - val_loss: 1.4662 - val_accuracy: 0.4268
# Epoch 3/50
# 281/281 [==============================] - 34s 119ms/step - loss: 1.4747 - accuracy: 0.4317 - val_loss: 1.3634 - val_accuracy: 0.4798
# Epoch 4/50
# 281/281 [==============================] - 34s 123ms/step - loss: 1.4350 - accuracy: 0.4429 - val_loss: 1.4085 - val_accuracy: 0.4539
# Epoch 5/50
# 281/281 [==============================] - 33s 117ms/step - loss: 1.3717 - accuracy: 0.4666 - val_loss: 1.3049 - val_accuracy: 0.4935
# Epoch 6/50
# 281/281 [==============================] - 33s 116ms/step - loss: 1.3295 - accuracy: 0.4796 - val_loss: 1.3566 - val_accuracy: 0.4579
# Epoch 7/50
# 281/281 [==============================] - 32s 115ms/step - loss: 1.3311 - accuracy: 0.4870 - val_loss: 1.2967 - val_accuracy: 0.4789
# Epoch 8/50
# 281/281 [==============================] - 33s 118ms/step - loss: 1.2983 - accuracy: 0.4940 - val_loss: 1.2428 - val_accuracy: 0.5002
# Epoch 9/50
# 281/281 [==============================] - 32s 115ms/step - loss: 1.2599 - accuracy: 0.5145 - val_loss: 1.2708 - val_accuracy: 0.4980
# Epoch 10/50
# 281/281 [==============================] - 32s 114ms/step - loss: 1.2756 - accuracy: 0.5061 - val_loss: 1.3060 - val_accuracy: 0.5109
# Epoch 11/50
# 281/281 [==============================] - 32s 114ms/step - loss: 1.2404 - accuracy: 0.5217 - val_loss: 1.2889 - val_accuracy: 0.5016
# Epoch 12/50
# 281/281 [==============================] - 32s 114ms/step - loss: 1.2281 - accuracy: 0.5306 - val_loss: 1.1963 - val_accuracy: 0.5367
# Epoch 13/50
# 281/281 [==============================] - 32s 114ms/step - loss: 1.2105 - accuracy: 0.5353 - val_loss: 1.1735 - val_accuracy: 0.5501
# Epoch 14/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.1921 - accuracy: 0.5380 - val_loss: 1.1864 - val_accuracy: 0.5300
# Epoch 15/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.1717 - accuracy: 0.5528 - val_loss: 1.2147 - val_accuracy: 0.5305
# Epoch 16/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.1888 - accuracy: 0.5419 - val_loss: 1.2298 - val_accuracy: 0.5318
# Epoch 17/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.1643 - accuracy: 0.5549 - val_loss: 1.2596 - val_accuracy: 0.5167
# Epoch 18/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.1480 - accuracy: 0.5578 - val_loss: 1.2206 - val_accuracy: 0.5483
# Epoch 19/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.1256 - accuracy: 0.5711 - val_loss: 1.1412 - val_accuracy: 0.5576
# Epoch 20/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.1286 - accuracy: 0.5721 - val_loss: 1.1323 - val_accuracy: 0.5826
# Epoch 21/50
# 281/281 [==============================] - 32s 115ms/step - loss: 1.0823 - accuracy: 0.5873 - val_loss: 1.1797 - val_accuracy: 0.5634
# Epoch 22/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.0686 - accuracy: 0.5820 - val_loss: 1.1017 - val_accuracy: 0.5852
# Epoch 23/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.0725 - accuracy: 0.5892 - val_loss: 1.1136 - val_accuracy: 0.5821
# Epoch 24/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.0791 - accuracy: 0.5884 - val_loss: 1.0450 - val_accuracy: 0.5888
# Epoch 25/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.0440 - accuracy: 0.6025 - val_loss: 1.0773 - val_accuracy: 0.5946
# Epoch 26/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.0432 - accuracy: 0.6038 - val_loss: 1.0848 - val_accuracy: 0.6004
# Epoch 27/50
# 281/281 [==============================] - 32s 112ms/step - loss: 1.0708 - accuracy: 0.5934 - val_loss: 1.0189 - val_accuracy: 0.6030
# Epoch 28/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.0136 - accuracy: 0.6127 - val_loss: 1.0780 - val_accuracy: 0.5839
# Epoch 29/50
# 281/281 [==============================] - 32s 113ms/step - loss: 1.0031 - accuracy: 0.6139 - val_loss: 1.0342 - val_accuracy: 0.6017
# Epoch 30/50
# 281/281 [==============================] - 32s 114ms/step - loss: 0.9862 - accuracy: 0.6197 - val_loss: 1.0382 - val_accuracy: 0.6066
# Epoch 31/50
# 281/281 [==============================] - 32s 113ms/step - loss: 0.9915 - accuracy: 0.6212 - val_loss: 1.0671 - val_accuracy: 0.5915
# Epoch 32/50
# 281/281 [==============================] - 32s 113ms/step - loss: 0.9740 - accuracy: 0.6227 - val_loss: 1.0178 - val_accuracy: 0.6142
# Epoch 33/50
# 281/281 [==============================] - 33s 117ms/step - loss: 0.9530 - accuracy: 0.6388 - val_loss: 0.9861 - val_accuracy: 0.6222
# Epoch 34/50
# 281/281 [==============================] - 33s 117ms/step - loss: 0.9643 - accuracy: 0.6299 - val_loss: 1.0807 - val_accuracy: 0.5808
# Epoch 35/50
# 281/281 [==============================] - 32s 113ms/step - loss: 0.9804 - accuracy: 0.6284 - val_loss: 1.0098 - val_accuracy: 0.6128
# Epoch 36/50
# 281/281 [==============================] - 32s 114ms/step - loss: 0.9524 - accuracy: 0.6318 - val_loss: 0.9534 - val_accuracy: 0.6360
# Epoch 37/50
# 281/281 [==============================] - 32s 113ms/step - loss: 0.9575 - accuracy: 0.6326 - val_loss: 0.9949 - val_accuracy: 0.6039
# Epoch 38/50
# 281/281 [==============================] - 33s 116ms/step - loss: 0.9236 - accuracy: 0.6488 - val_loss: 1.0309 - val_accuracy: 0.6271
# Epoch 39/50
# 281/281 [==============================] - 32s 112ms/step - loss: 0.9193 - accuracy: 0.6487 - val_loss: 0.9587 - val_accuracy: 0.6333
# Epoch 40/50
# 281/281 [==============================] - 32s 112ms/step - loss: 0.9200 - accuracy: 0.6470 - val_loss: 0.9771 - val_accuracy: 0.6449
# Epoch 41/50
# 281/281 [==============================] - 31s 112ms/step - loss: 0.8997 - accuracy: 0.6608 - val_loss: 0.8644 - val_accuracy: 0.6684
# Epoch 42/50
# 281/281 [==============================] - 32s 112ms/step - loss: 0.8874 - accuracy: 0.6613 - val_loss: 0.9709 - val_accuracy: 0.6400
# Epoch 43/50
# 281/281 [==============================] - 31s 111ms/step - loss: 0.9070 - accuracy: 0.6596 - val_loss: 0.9451 - val_accuracy: 0.6569
# Epoch 44/50
# 281/281 [==============================] - 31s 112ms/step - loss: 0.8630 - accuracy: 0.6729 - val_loss: 0.9982 - val_accuracy: 0.6297
# Epoch 45/50
# 281/281 [==============================] - 33s 117ms/step - loss: 0.8892 - accuracy: 0.6578 - val_loss: 0.9165 - val_accuracy: 0.6618
# Epoch 46/50
# 281/281 [==============================] - 31s 112ms/step - loss: 0.8555 - accuracy: 0.6737 - val_loss: 0.8415 - val_accuracy: 0.6836
# Epoch 47/50
# 281/281 [==============================] - 31s 111ms/step - loss: 0.8309 - accuracy: 0.6834 - val_loss: 0.8483 - val_accuracy: 0.6840
# Epoch 48/50
# 281/281 [==============================] - 32s 113ms/step - loss: 0.8546 - accuracy: 0.6802 - val_loss: 0.8954 - val_accuracy: 0.6582
# Epoch 49/50
# 281/281 [==============================] - 31s 111ms/step - loss: 0.8338 - accuracy: 0.6828 - val_loss: 0.8510 - val_accuracy: 0.6845
# Epoch 50/50
# 281/281 [==============================] - 31s 112ms/step - loss: 0.8227 - accuracy: 0.6875 - val_loss: 0.8945 - val_accuracy: 0.6582

# %% [markdown]
# #### Visualize the model results

# %%
visualizing_result(history,epochs)

# %% [markdown]
# ## 10. Conclusion

# %% [markdown]
# *   We can observe that training accuracy and validation accuracy is almost similar indiciating good fit. Hence our underfiting and overfiting issue is resolved
# *   Training loss and validation loss are also almost similar indicating good  model fit
# *   Class rebalance definately helped as we can see the accuracy of model has increased drastically using the same model. The model is now able to handle minoirity classes better compare to earlier model and over all accuracy of the model is around **65%**
# *   We can further improve the performance of the model by tweaking the model
